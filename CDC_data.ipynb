# %%
import pandas as pd
import numpy as py

# %%
#Read csv file
csv_file = "CDC_data.csv"
cdc_df = pd.read_csv(csv_file)
cdc_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr          LocationDesc  \
# 0       2012     2012           WY               Wyoming
# 1       2012     2012           DC  District of Columbia
# 2       2011     2011           AL               Alabama
# 3       2013     2013           US              National
# 4       2011     2011           US              National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System        Physical Activity
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0       Obesity / Weight Status
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3  Physical Activity - Behavior
# ...

# %%
#only data from Question "Percent of adults aged 18 years and older who have obesity"

cdc_df_filtered = cdc_df.loc[cdc_df["Question"] == "Percent of adults aged 18 years and older who have obesity"]

# %%
#filter for only 2014 to match other data set
cdc_df_filtered2 = cdc_df_filtered.loc[cdc_df["YearStart"] == 2014]
cdc_df_filtered2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1512 entries, 28 to 63017
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   1512 non-null   int64
#  1   YearEnd                     1512 non-null   int64
#  2   LocationAbbr                1512 non-null   object
#  3   LocationDesc                1512 non-null   object
#  4   Datasource                  1512 non-null   object
#  5   Class                       1512 non-null   object
#  6   Topic                       1512 non-null   object
#  7   Question                    1512 non-null   object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             1512 non-null   object
#  10  Data_Value                  1369 non-null   float64
#  11  Data_Value_Alt              1369 non-null   float64
#  12  Data_Value_Footnote_Symbol  143 non-null    object
# ...

# %%
#dropna from Gender column
cdc_df_filtered3 = cdc_df_filtered2
cdc_df_filtered3.dropna(subset = ["Gender"], inplace=True)
cdc_df_filtered3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108 entries, 513 to 62774
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   108 non-null    int64
#  1   YearEnd                     108 non-null    int64
#  2   LocationAbbr                108 non-null    object
#  3   LocationDesc                108 non-null    object
#  4   Datasource                  108 non-null    object
#  5   Class                       108 non-null    object
#  6   Topic                       108 non-null    object
#  7   Question                    108 non-null    object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             108 non-null    object
#  10  Data_Value                  108 non-null    float64
#  11  Data_Value_Alt              108 non-null    float64
#  12  Data_Value_Footnote_Symbol  0 non-null      object
# ...

# %%
cdc_df_filtered3.head()
# Out:
#       YearStart  YearEnd LocationAbbr LocationDesc  \
# 513        2014     2014           AZ      Arizona
# 3985       2014     2014           VA     Virginia
# 5973       2014     2014           NE     Nebraska
# 6859       2014     2014           MD     Maryland
# 7826       2014     2014           LA    Louisiana
#
#                                       Datasource                    Class  \
# 513   Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3985  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 5973  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 6859  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 7826  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                         Topic  \
# 513   Obesity / Weight Status
# 3985  Obesity / Weight Status
# 5973  Obesity / Weight Status
# 6859  Obesity / Weight Status
# 7826  Obesity / Weight Status
#
# ...

# %%
#Retrieve relevant columns
cdc_df_filtered4 = cdc_df_filtered3[['LocationAbbr', 'Data_Value_Alt', 'Gender']]

# %%
#Rename Columns
cdc_df_clean = cdc_df_filtered4.rename(columns={
    'LocationAbbr': 'stateid',
    'Data_Value_Alt': 'percentage(obese)',
    'Gender': 'gender'
})

# %%
#save to a csv file
cdc_df_clean.to_csv("cdc_data_clean.csv", index=True)
