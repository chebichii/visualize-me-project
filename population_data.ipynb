# %%
import pandas as pd
import numpy as py

# %%
#Read csv file
csv_file = "census_population_data.csv"
population_df = pd.read_csv(csv_file)
population_df.head()
# Out:
#    SUMLEV REGION DIVISION  STATE           NAME  CENSUS2010POP  \
# 0      10      0        0      0  United States      308745538
# 1      40      3        6      1        Alabama        4779736
# 2      40      4        9      2         Alaska         710231
# 3      40      4        8      4        Arizona        6392017
# 4      40      3        7      5       Arkansas        2915918
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  ...  \
# 0          308758105        309321666        311556874        313830990  ...
# 1            4780125          4785437          4799069          4815588  ...
# 2             710249           713910           722128           730443  ...
# 3            6392288          6407172          6472643          6554978  ...
# 4            2916031          2921964          2940667          2952164  ...
#
#    RDOMESTICMIG2019  RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  \
# ...

# %%
#Retrieve relevant columns
pop_remove = population_df[['NAME', 'CENSUS2010POP', 'POPESTIMATE2014']]
pop_remove.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NAME             53 non-null     object
#  1   CENSUS2010POP    53 non-null     int64
#  2   POPESTIMATE2014  53 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.4+ KB

# %%
#Rename Columns
population_df_clean = pop_remove.rename(columns={
    'NAME': 'state',
    'CENSUS2010POP': 'totalpopulation(census 2010)',
    'POPESTIMATE2014': 'population(est 2014)'
})

# %%
#save to a csv file
population_df_clean.to_csv("population_df_clean.csv", index=True)
