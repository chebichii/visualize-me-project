# %%
import pandas as pd, requests, json

# %%
file = pd.read_csv("data_proj2.csv")
file.head()
# Out:
#    year stateabbr statename    cityname  obesitypercentage  Population2010  \
# 0  2014        ID     Idaho  Boise City               23.8            5604
# 1  2014        ID     Idaho  Boise City               28.3            5382
# 2  2014        ID     Idaho  Boise City               27.6             979
# 3  2014        ID     Idaho  Boise City               29.0            5746
# 4  2014        ID     Idaho  Boise City               27.2            6328
#
#    latitude   longitude
# 0     43.59 -116.180835
# 1     43.60 -116.243609
# 2     43.61 -116.336938
# 3     43.61 -116.259400
# 4     43.67 -116.264532

# %%
file = file.round({'longitude': 2})
file
# Out:
#        year stateabbr      statename    cityname  obesitypercentage  \
# 0      2014        ID          Idaho  Boise City               23.8
# 1      2014        ID          Idaho  Boise City               28.3
# 2      2014        ID          Idaho  Boise City               27.6
# 3      2014        ID          Idaho  Boise City               29.0
# 4      2014        ID          Idaho  Boise City               27.2
# ...     ...       ...            ...         ...                ...
# 25462  2014        SC  South Carolin  Charleston               43.3
# 25463  2014        CA     California      Oxnard               22.2
# 25464  2014        TX          Texas     Garland               32.4
# 25465  2014        MA  Massachusetts      Boston               21.2
# 25466  2014        TN      Tennessee     Memphis               39.5
#
#        Population2010  latitude  longitude
# 0                5604     43.59    -116.18
# 1                5382     43.60    -116.24
# ...

# %%
file[['latitude', 'longitude']] = file[['latitude', 'longitude']].astype(object)

# %%
file['combined'] = file.apply(lambda x: list([x['latitude'],
                                    
                                        
                                        x['longitude']]),axis=1)  
file
# Out:
#        year stateabbr      statename    cityname  obesitypercentage  \
# 0      2014        ID          Idaho  Boise City               23.8
# 1      2014        ID          Idaho  Boise City               28.3
# 2      2014        ID          Idaho  Boise City               27.6
# 3      2014        ID          Idaho  Boise City               29.0
# 4      2014        ID          Idaho  Boise City               27.2
# ...     ...       ...            ...         ...                ...
# 25462  2014        SC  South Carolin  Charleston               43.3
# 25463  2014        CA     California      Oxnard               22.2
# 25464  2014        TX          Texas     Garland               32.4
# 25465  2014        MA  Massachusetts      Boston               21.2
# 25466  2014        TN      Tennessee     Memphis               39.5
#
#        Population2010  latitude  longitude          combined
# 0                5604     43.59    -116.18  [43.59, -116.18]
# ...

# %%
file['combined'] = file['combined'].astype(object)

# %%
file.to_json(r'C:\Users\momad\Desktop\pro2\data3.json',orient='records')

# %%
file.to_dict(r'C:\Users\momad\Desktop\pro2\data.json',orient='records')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ba7aba844f37> in <module>
# ----> 1 file.to_dict(r'C:\Users\momad\Desktop\pro2\data.json',orient='records')
#
# TypeError: to_dict() got multiple values for argument 'orient'

# %%
## convert dataframe to json

my = with open('temp.json', 'w') as f:
    f.write(file.to_json(orient='records', lines=True))
my
# Out:
#   File "<ipython-input-16-1879a9da8dd2>", line 3
#     my = with open('temp.json', 'w') as f:
#             ^
# SyntaxError: invalid syntax

# %%
## reference for converting pandas dataframe to geogson:
## https://geoffboeing.com/2015/10/exporting-python-data-geojson/

# %%
def df_to_geojson(file, properties, lat='latitude', lon='longitude'):
    """
    Turn a dataframe containing point data into a geojson formatted python dictionary
    
    df : the dataframe to convert to geojson
    properties : a list of columns in the dataframe to turn into geojson feature properties
    lat : the name of the column in the dataframe that contains latitude data
    lon : the name of the column in the dataframe that contains longitude data
    """
    
    # create a new python dict to contain our geojson data, using geojson format
    geojson = {'type':'FeatureCollection', 'features':[]}

    # loop through each row in the dataframe and convert each row to geojson format
    for _, row in file.iterrows():
        # create a feature template to fill in
        feature = {'type':'Feature',
                   'properties':{},
                   'geometry':{'type':'Polygon',
                               'coordinates':[]}}

        # fill in the coordinates
        feature['geometry']['coordinates'] = [row[lon],row[lat]]

        # for each column, get the value and add it as a new feature property
        for prop in properties:
            feature['properties'][prop] = row[prop]
        
        # add this feature (aka, converted dataframe row) to the list of features inside our dict
        geojson['features'].append(feature)
    
    return geojson

# %%
useful_columns = ['year', 'stateabbr', 'statename', 'obesitypercentage', 'Population2010']
geojson_dict = df_to_geojson(file, properties=useful_columns)
geojson_str = json.dumps(geojson_dict, indent=2)

# %%
# save the geojson result to a file
output_filename = 'dataset.geojson'
with open(output_filename, 'w') as output_file:
    output_file.write('var dataset = {};'.format(geojson_str))
    
# how many features did we save to the geojson file?
print('{} geotagged features saved to file'.format(len(geojson_dict['features'])))
# Out:
# 25467 geotagged features saved to file

# %%
## link to avi dashboard:
#https://ncov2019.live/data
